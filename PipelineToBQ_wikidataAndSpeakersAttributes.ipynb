# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/MyDrive/EPFL HS21/Applied data analysis CS-401/Project/ADA team winner/Project Milestone 2
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/MyDrive/EPFL HS21/Applied data analysis CS-401/Project/ADA team winner/Project Milestone 2

# %%
import json
import pandas as pd

# %% [markdown]
# # Loading the wikidata in Google BigQuery (BQ)
# The goal of this file is to load the wikidata dataset from Google drive into BQ.
#
# There are 2 types of datasets:
# 1. speaker attributes
# 2. wikidata
#
# The initial files to be loaded in BQ are in Google Drive. This python script opens by chunk the large large files (so that they fit in memory) and then loads uploads them in BQ after some slight pre-processing.

# %%
# Setup of the Google Cloud utilities
from google.cloud import bigquery
from google.oauth2 import service_account
import json, os

# Google Cloud services
gcp_service_account_credentials_json_filename = 'epfl-course-f41b0ed796f9.json' #need to upload the json credential files to the root directory of the google colab files
os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = gcp_service_account_credentials_json_filename
credentials = service_account.Credentials.from_service_account_file(gcp_service_account_credentials_json_filename, scopes=['https://www.googleapis.com/auth/bigquery', 'https://www.googleapis.com/auth/drive'])
project_id = 'epfl-course'
bigquery_client = bigquery.Client(credentials=credentials, project=project_id)
bigquery_client = bigquery.Client()

#Execute a query in BQ
def bq_execute_query(query, mode="INTERACTIVE", wait=False, to_dataframe=False):
    job_config = bigquery.QueryJobConfig(priority="bigquery.QueryPriority.{}".format(mode)) # Run at BATCH priority, which won't count toward concurrent rate limit, otherwise INTERACTIVE.
    query_job = bigquery_client.query(query, job_config)
    if wait==True:
        print("Executed BQ query: ", query_job.result())
    if to_dataframe==True:
        return(query_job.to_dataframe())
    else:
        return(query_job)

#Upload a DF to BQ
def upload_df_to_bq(df, bq_destination_table, write_disposition="WRITE_APPEND"):
    #bq_table_name = "epfl-course.dataset.table"
    job_config = bigquery.LoadJobConfig(create_disposition="CREATE_IF_NEEDED", 
                                        write_disposition=write_disposition)
    #source_format=bigquery.SourceFormat.NEWLINE_DELIMITED_JSON
    upload_df_to_bq_job = bigquery_client.load_table_from_dataframe(
        df, bq_destination_table, job_config = job_config)
    print("Uploaded DF to BQ: ",upload_df_to_bq_job.result()) 

def upload_parquet_to_bq(parquet_file, bq_destination_table, write_disposition="WRITE_APPEND"):
    job_config = bigquery.LoadJobConfig(create_disposition="CREATE_IF_NEEDED", 
                                        write_disposition=write_disposition,
                                        schema=[
                                            bigquery.SchemaField("aliases", "STRING", mode="REPEATED"), #, fields=[bigquery.SchemaField('list', 'RECORD', mode="REPEATED", fields=[bigquery.SchemaField('element', 'STRING')])]),
                                            bigquery.SchemaField("date_of_birth", "STRING", mode="REPEATED"), #, fields=[bigquery.SchemaField('list', 'RECORD', mode="REPEATED", fields=[bigquery.SchemaField('element', 'STRING')])]),
                                            bigquery.SchemaField("nationality", "STRING", mode="REPEATED"), #, fields=[bigquery.SchemaField('list', 'RECORD', mode="REPEATED", fields=[bigquery.SchemaField('element', 'STRING')])]),
                                            bigquery.SchemaField("gender", "STRING", mode="REPEATED"), #, fields=[bigquery.SchemaField('list', 'RECORD', mode="REPEATED", fields=[bigquery.SchemaField('element', 'STRING')])]),
                                            bigquery.SchemaField("ethnic_group", "STRING", mode="REPEATED"), #, fields=[bigquery.SchemaField('list', 'RECORD', mode="REPEATED", fields=[bigquery.SchemaField('element', 'STRING')])]),
                                            bigquery.SchemaField("occupation", "STRING", mode="REPEATED"), #, fields=[bigquery.SchemaField('list', 'RECORD', mode="REPEATED", fields=[bigquery.SchemaField('element', 'STRING')])]),
                                            bigquery.SchemaField("party", "STRING", mode="REPEATED"), #, fields=[bigquery.SchemaField('list', 'RECORD', mode="REPEATED", fields=[bigquery.SchemaField('element', 'STRING')])]),
                                            bigquery.SchemaField("academic_degree", "STRING", mode="REPEATED"), #, fields=[bigquery.SchemaField('list', 'RECORD', mode="REPEATED", fields=[bigquery.SchemaField('element', 'STRING')])]),
                                            bigquery.SchemaField("candidacy", "STRING", mode="REPEATED"), #, fields=[bigquery.SchemaField('list', 'RECORD', mode="REPEATED", fields=[bigquery.SchemaField('element', 'STRING')])]),
                                            bigquery.SchemaField("religion", "STRING", mode="REPEATED"), #, fields=[bigquery.SchemaField('list', 'RECORD', mode="REPEATED", fields=[bigquery.SchemaField('element', 'STRING')])]),
                                        ]
                                        )
    source_format=bigquery.SourceFormat.PARQUET
    upload_file_to_bq_job = bigquery_client.load_table_from_file(
          parquet_file, 
          bq_destination_table, 
          job_config = job_config)
    print("Uploaded Parquet to BQ: ",upload_file_to_bq_job.result()) 

#Upload a JSON to BQ
def upload_json_to_bq(json_object, bq_table):
    try:
        job_config = bigquery.LoadJobConfig()
        job_config.autodetect = False #Change to True if the table on BQ does not exits
        job_config.max_bad_records = 0
        job_config.ignore_unknown_values = True
        job_config.source_format = 'NEWLINE_DELIMITED_JSON'
        job_config.create_disposition= "CREATE_IF_NEEDED"
        job_config.write_disposition= "WRITE_APPEND"
        job = bigquery_client.load_table_from_file(json_object, bq_table, job_config = job_config)
        print("Loaded JSON to BQ table {} as job {}".format(bq_table, job.result()))
        assert job.job_type == 'load'
        assert job.state == 'DONE'
    except:
        print("ERROR Could not load JSON to BQ table {} as job {}".format(bq_table, job.result()))

# %% [markdown]
# ## Load Speakers Attributes to BQ

# %%
parquet_folder_location = "Project datasets/speaker_attributes.parquet"
#get a list of files to be uploaded
list_of_paquet_files_to_upload = [f for f in os.listdir(parquet_folder_location) if os.path.isfile(os.path.join(parquet_folder_location, f)) and "SUCCESS" not in f and ".crc" not in f]
list_of_paquet_files_to_upload.sort()

# %%
list_of_paquet_files_to_upload
# Out:
# ['part-00000-0d587965-3d8f-41ce-9771-5b8c9024dce9-c000.snappy.parquet',
#  'part-00001-0d587965-3d8f-41ce-9771-5b8c9024dce9-c000.snappy.parquet',
#  'part-00002-0d587965-3d8f-41ce-9771-5b8c9024dce9-c000.snappy.parquet',
#  'part-00003-0d587965-3d8f-41ce-9771-5b8c9024dce9-c000.snappy.parquet',
#  'part-00004-0d587965-3d8f-41ce-9771-5b8c9024dce9-c000.snappy.parquet',
#  'part-00005-0d587965-3d8f-41ce-9771-5b8c9024dce9-c000.snappy.parquet',
#  'part-00006-0d587965-3d8f-41ce-9771-5b8c9024dce9-c000.snappy.parquet',
#  'part-00007-0d587965-3d8f-41ce-9771-5b8c9024dce9-c000.snappy.parquet',
#  'part-00008-0d587965-3d8f-41ce-9771-5b8c9024dce9-c000.snappy.parquet',
#  'part-00009-0d587965-3d8f-41ce-9771-5b8c9024dce9-c000.snappy.parquet',
#  'part-00010-0d587965-3d8f-41ce-9771-5b8c9024dce9-c000.snappy.parquet',
#  'part-00011-0d587965-3d8f-41ce-9771-5b8c9024dce9-c000.snappy.parquet',
#  'part-00012-0d587965-3d8f-41ce-9771-5b8c9024dce9-c000.snappy.parquet',
#  'part-00013-0d587965-3d8f-41ce-9771-5b8c9024dce9-c000.snappy.parquet',
#  'part-00014-0d587965-3d8f-41ce-9771-5b8c9024dce9-c000.snappy.parquet',
#  'part-00015-0d587965-3d8f-41ce-9771-5b8c9024dce9-c000.snappy.parquet']

# %%
# For every file to be uploaded, open the parquet file, convert it as dataframe (df) and upload it to BQ.
counter = 0
for file_name in list_of_paquet_files_to_upload:
  file_path = os.path.join(parquet_folder_location, file_name)
  print("Uploading ", file_name)

  #read file
  df = pd.read_parquet(file_path)

  #upload file to BQ
  bq_destination_table_suffix = str(counter).zfill(3)
  bq_destination_table = "epfl-course.wikidata_parquet.speaker_attributes" + bq_destination_table_suffix
  print("New table name: ", bq_destination_table)
  upload_df_to_bq(df, bq_destination_table)
  counter += 1
  pass
# Out:
# Uploading  part-00000-0d587965-3d8f-41ce-9771-5b8c9024dce9-c000.snappy.parquet
# /usr/local/lib/python3.7/dist-packages/google/cloud/bigquery/_pandas_helpers.py:275: UserWarning: Unable to determine type of column 'aliases'.
#   warnings.warn(u"Unable to determine type of column '{}'.".format(column))
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fe309ca1110>
# Uploading  part-00001-0d587965-3d8f-41ce-9771-5b8c9024dce9-c000.snappy.parquet
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fe2f9342cd0>
# Uploading  part-00002-0d587965-3d8f-41ce-9771-5b8c9024dce9-c000.snappy.parquet
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fe2defebcd0>
# Uploading  part-00003-0d587965-3d8f-41ce-9771-5b8c9024dce9-c000.snappy.parquet
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fe310659e90>
# Uploading  part-00004-0d587965-3d8f-41ce-9771-5b8c9024dce9-c000.snappy.parquet
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fe30a029f90>
# Uploading  part-00005-0d587965-3d8f-41ce-9771-5b8c9024dce9-c000.snappy.parquet
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fe30a0d5dd0>
# Uploading  part-00006-0d587965-3d8f-41ce-9771-5b8c9024dce9-c000.snappy.parquet
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fe310bd0550>
# Uploading  part-00007-0d587965-3d8f-41ce-9771-5b8c9024dce9-c000.snappy.parquet
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fe30c0d6fd0>
# Uploading  part-00008-0d587965-3d8f-41ce-9771-5b8c9024dce9-c000.snappy.parquet
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fe2f9cc8210>
# Uploading  part-00009-0d587965-3d8f-41ce-9771-5b8c9024dce9-c000.snappy.parquet
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fe2f9342f50>
# Uploading  part-00010-0d587965-3d8f-41ce-9771-5b8c9024dce9-c000.snappy.parquet
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fe30aab6790>
# Uploading  part-00011-0d587965-3d8f-41ce-9771-5b8c9024dce9-c000.snappy.parquet
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fe2f9f19850>
# Uploading  part-00012-0d587965-3d8f-41ce-9771-5b8c9024dce9-c000.snappy.parquet
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fe30ac68590>
# Uploading  part-00013-0d587965-3d8f-41ce-9771-5b8c9024dce9-c000.snappy.parquet
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fe30c8dc550>
# Uploading  part-00014-0d587965-3d8f-41ce-9771-5b8c9024dce9-c000.snappy.parquet
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fe2f9de8050>
# Uploading  part-00015-0d587965-3d8f-41ce-9771-5b8c9024dce9-c000.snappy.parquet
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fe30ca84050>

# %%
#schema of the files uploaded to BQ
df.dtypes
# Out:
# aliases               object
# date_of_birth         object
# nationality           object
# gender                object
# lastrevid              int64
# ethnic_group          object
# US_congress_bio_ID    object
# occupation            object
# party                 object
# academic_degree       object
# id                    object
# label                 object
# candidacy             object
# type                  object
# religion              object
# dtype: object

# %% [markdown]
# ## Load wikidata to BQ

# %%
#Load the wikidata to BQ by chunks of 100000 rows
wikidata_labels_descriptions_df = pd.read_csv("Project datasets/wikidata_labels_descriptions.csv.bz2", 
                                              compression='bz2',
                                              chunksize= 100000) #read by chunk to fit in memory

# %%
bq_destination_table_labels = "epfl-course.wikidata_parquet.wikidata_labels_descriptions"
counter = 0
for chunk in wikidata_labels_descriptions_df:
  print("Uploading chunk ", counter)
  upload_df_to_bq(chunk, bq_destination_table_labels)
  counter += 1
# Out:
# Uploading chunk  0
# /usr/local/lib/python3.7/dist-packages/google/cloud/bigquery/_pandas_helpers.py:275: UserWarning: Unable to determine type of column 'QID'.
#   warnings.warn(u"Unable to determine type of column '{}'.".format(column))
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb18c927cd0>
# Uploading chunk  1
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb1883d19d0>
# Uploading chunk  2
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb188435810>
# Uploading chunk  3
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb18d6b8950>
# Uploading chunk  4
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb188a43d50>
# Uploading chunk  5
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb18614fed0>
# Uploading chunk  6
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb18524e250>
# Uploading chunk  7
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb1842c11d0>
# Uploading chunk  8
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb1843036d0>
# Uploading chunk  9
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb18e365bd0>
# Uploading chunk  10
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb18b1266d0>
# Uploading chunk  11
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb18866ff50>
# Uploading chunk  12
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb1871d5c90>
# Uploading chunk  13
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb1866c6110>
# Uploading chunk  14
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb186b0fa50>
# Uploading chunk  15
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb186757890>
# Uploading chunk  16
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb18c8ed950>
# Uploading chunk  17
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb188530390>
# Uploading chunk  18
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb185c23950>
# Uploading chunk  19
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb184dd3610>
# Uploading chunk  20
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb184e17850>
# Uploading chunk  21
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb1842c4510>
# Uploading chunk  22
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb18d5c0450>
# Uploading chunk  23
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb1889df0d0>
# Uploading chunk  24
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb1868db690>
# Uploading chunk  25
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb1858ae3d0>
# Uploading chunk  26
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb18589fd10>
# Uploading chunk  27
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb18d6ce490>
# Uploading chunk  28
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb18d80bb50>
# Uploading chunk  29
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb1886ad410>
# Uploading chunk  30
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb18651b2d0>
# Uploading chunk  31
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb1849e7b50>
# Uploading chunk  32
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb184a05c10>
# Uploading chunk  33
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb1832d74d0>
# Uploading chunk  34
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb1885c08d0>
# Uploading chunk  35
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb188b50990>
# Uploading chunk  36
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb185fcc950>
# Uploading chunk  37
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb183e86cd0>
# Uploading chunk  38
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb183effad0>
# Uploading chunk  39
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb1860f9810>
# Uploading chunk  40
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb189064290>
# Uploading chunk  41
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb186497f10>
# Uploading chunk  42
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb1847e95d0>
# Uploading chunk  43
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb1804db790>
# Uploading chunk  44
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb1847e9ed0>
# Uploading chunk  45
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb1807f56d0>
# Uploading chunk  46
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb18b14a250>
# Uploading chunk  47
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb1868adbd0>
# Uploading chunk  48
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb184c45d10>
# Uploading chunk  49
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb183203f10>
# Uploading chunk  50
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb183279f90>
# Uploading chunk  51
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb1861acf50>
# Uploading chunk  52
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb18d32dd90>
# Uploading chunk  53
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb186bc6f10>
# Uploading chunk  54
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb1858ded90>
# Uploading chunk  55
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb183fe1ed0>
# Uploading chunk  56
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb1858e7090>
# Uploading chunk  57
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb186598d10>
# Uploading chunk  58
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb18d25dc90>
# Uploading chunk  59
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb186aa2150>
# Uploading chunk  60
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb1854c2990>
# Uploading chunk  61
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb1836b7350>
# Uploading chunk  62
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb1836aed90>
# Uploading chunk  63
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb18d357a50>
# Uploading chunk  64
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb18d4eca10>
# Uploading chunk  65
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb186d13850>
# Uploading chunk  66
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb185385c90>
# Uploading chunk  67
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb183dc40d0>
# Uploading chunk  68
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb183da2090>
# Uploading chunk  69
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb18846fa10>
# Uploading chunk  70
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb187251f50>
# Uploading chunk  71
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb18d2d0c50>
# Uploading chunk  72
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb1872260d0>
# Uploading chunk  73
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb185987d10>
# Uploading chunk  74
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb185940e90>
# Uploading chunk  75
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb185a687d0>
# Uploading chunk  76
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb1807da0d0>
# Uploading chunk  77
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb188c34510>
# Uploading chunk  78
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb185f4e9d0>
# Uploading chunk  79
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb1817e78d0>
# Uploading chunk  80
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb1817e70d0>
# Uploading chunk  81
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb18856fc10>
# Uploading chunk  82
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb18dfcac90>
# Uploading chunk  83
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb188d77a10>
# Uploading chunk  84
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb1863ea6d0>
# Uploading chunk  85
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb184c1f290>
# Uploading chunk  86
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb184c1b690>
# Uploading chunk  87
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb18d463c50>
# Uploading chunk  88
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb183ea4d50>
# Uploading chunk  89
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb18b0c58d0>
# Uploading chunk  90
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb186be5bd0>
# Uploading chunk  91
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb185221050>
# Uploading chunk  92
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb185207910>
# Uploading chunk  93
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb1807c87d0>
# Uploading chunk  94
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb18e3773d0>
# Uploading chunk  95
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb18de95f90>
# Uploading chunk  96
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb188497650>
# Uploading chunk  97
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb185de4750>
# Uploading chunk  98
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb185dcf390>
# Uploading chunk  99
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb18d6dfb10>
# Uploading chunk  100
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb18673fad0>
# Uploading chunk  101
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb18d3a03d0>
# Uploading chunk  102
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb18686b510>
# Uploading chunk  103
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb18330cb90>
# Uploading chunk  104
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb183328b90>
# Uploading chunk  105
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb18d1b55d0>
# Uploading chunk  106
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb17f94ae50>
# Uploading chunk  107
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb188f18890>
# Uploading chunk  108
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb1887f4310>
# Uploading chunk  109
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb18610c790>
# Uploading chunk  110
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb186229950>
# Uploading chunk  111
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb18deb1710>
# Uploading chunk  112
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb18de13510>
# Uploading chunk  113
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb188eea8d0>
# Uploading chunk  114
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb188fe8b90>
# Uploading chunk  115
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb1814e0990>
# Uploading chunk  116
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb1814d3310>
# Uploading chunk  117
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb183e93310>
# Uploading chunk  118
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb1858e6450>
# Uploading chunk  119
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb184f04e90>
# Uploading chunk  120
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb189131fd0>
# Uploading chunk  121
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb186912690>
# Uploading chunk  122
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb186917ed0>
# Uploading chunk  123
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb18915b710>
# Uploading chunk  124
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb183df2890>
# Uploading chunk  125
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb183df8dd0>
# Uploading chunk  126
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb18defddd0>
# Uploading chunk  127
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb187429850>
# Uploading chunk  128
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb187417850>
# Uploading chunk  129
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb1855239d0>
# Uploading chunk  130
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb185233150>
# Uploading chunk  131
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb188f48fd0>
# Uploading chunk  132
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb183df8710>
# Uploading chunk  133
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb18c862c10>
# Uploading chunk  134
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb18c8d88d0>
# Uploading chunk  135
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb183ca1610>
# Uploading chunk  136
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb184e9d190>
# Uploading chunk  137
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb188fc8810>
# Uploading chunk  138
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb18d45c6d0>
# Uploading chunk  139
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb187037950>
# Uploading chunk  140
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb186fbfe50>
# Uploading chunk  141
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb18b136cd0>
# Uploading chunk  142
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb18723a950>
# Uploading chunk  143
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb184c3e510>
# Uploading chunk  144
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb1861ce810>
# Uploading chunk  145
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb18711dc50>
# Uploading chunk  146
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb187101990>
# Uploading chunk  147
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb185502990>
# Uploading chunk  148
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb1885529d0>
# Uploading chunk  149
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb186d0e4d0>
# Uploading chunk  150
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb1841d66d0>
# Uploading chunk  151
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb186c7e3d0>
# Uploading chunk  152
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb186eed890>
# Uploading chunk  153
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb189114710>
# Uploading chunk  154
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb188fe8bd0>
# Uploading chunk  155
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb18d660c50>
# Uploading chunk  156
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb184b27c90>
# Uploading chunk  157
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb180d12d90>
# Uploading chunk  158
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb18411c890>
# Uploading chunk  159
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb186056950>
# Uploading chunk  160
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb18ddc7c90>
# Uploading chunk  161
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb18e0a8c50>
# Uploading chunk  162
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb1862de610>
# Uploading chunk  163
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb183b27fd0>
# Uploading chunk  164
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb183b3ca50>
# Uploading chunk  165
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb1863f4290>
# Uploading chunk  166
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb1864eec10>
# Uploading chunk  167
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb18e7fd3d0>
# Uploading chunk  168
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb185f2e250>
# Uploading chunk  169
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb180bd2a10>
# Uploading chunk  170
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb185f2e490>
# Uploading chunk  171
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb186b01fd0>
# Uploading chunk  172
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb184030e90>
# Uploading chunk  173
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb17f08f190>
# Uploading chunk  174
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb186a15850>
# Uploading chunk  175
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb183e2aa50>
# Uploading chunk  176
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb183e392d0>
# Uploading chunk  177
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb187208a10>
# Uploading chunk  178
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb1886413d0>
# Uploading chunk  179
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb17f1eb790>
# Uploading chunk  180
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb186f93b50>
# Uploading chunk  181
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb184734810>
# Uploading chunk  182
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb184585ed0>
# Uploading chunk  183
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb1868b3f90>
# Uploading chunk  184
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb184ad0490>
# Uploading chunk  185
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb187389190>
# Uploading chunk  186
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb188641810>
# Uploading chunk  187
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb188820090>
# Uploading chunk  188
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb185674690>
# Uploading chunk  189
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb184338a50>
# Uploading chunk  190
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb18b0e6d50>
# Uploading chunk  191
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb18d245dd0>
# Uploading chunk  192
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb1890fd510>
# Uploading chunk  193
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb1838efed0>
# Uploading chunk  194
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb1890a2d90>
# Uploading chunk  195
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb1890fd850>
# Uploading chunk  196
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb188491990>
# Uploading chunk  197
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb18636add0>
# Uploading chunk  198
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb188911710>
# Uploading chunk  199
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb185596d90>
# Uploading chunk  200
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb1855fe410>
# Uploading chunk  201
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb186a082d0>
# Uploading chunk  202
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb1888f3490>
# Uploading chunk  203
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb18e38ba90>
# Uploading chunk  204
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb1888f2ad0>
# Uploading chunk  205
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb186c22d10>
# Uploading chunk  206
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb186c02990>
# Uploading chunk  207
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb18d45e650>
# Uploading chunk  208
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb184227b50>
# Uploading chunk  209
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb188ffcf90>
# Uploading chunk  210
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb18561afd0>
# Uploading chunk  211
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb185ba2350>
# Uploading chunk  212
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb1865ef950>
# Uploading chunk  213
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb18d440210>
# Uploading chunk  214
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb18478b410>
# Uploading chunk  215
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb185dc0b50>
# Uploading chunk  216
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb18490a890>
# Uploading chunk  217
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb1886e06d0>
# Uploading chunk  218
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb181a56590>
# Uploading chunk  219
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb18d1b6810>
# Uploading chunk  220
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb18595bc50>
# Uploading chunk  221
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb1871a3b90>
# Uploading chunk  222
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb1887cdd50>
# Uploading chunk  223
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb184da2fd0>
# Uploading chunk  224
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb184d635d0>
# Uploading chunk  225
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb184dafdd0>
# Uploading chunk  226
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb180765450>
# Uploading chunk  227
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb183d1c750>
# Uploading chunk  228
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb1940716d0>
# Uploading chunk  229
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb185e70490>
# Uploading chunk  230
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb1860e8d90>
# Uploading chunk  231
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb18d5ac1d0>
# Uploading chunk  232
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb186dffb90>
# Uploading chunk  233
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb18364c510>
# Uploading chunk  234
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb1854a42d0>
# Uploading chunk  235
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb188ccbf90>
# Uploading chunk  236
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb188ccb410>
# Uploading chunk  237
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb19443e650>
# Uploading chunk  238
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb186174cd0>
# Uploading chunk  239
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb185f22750>
# Uploading chunk  240
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb18474a990>
# Uploading chunk  241
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb188e87850>
# Uploading chunk  242
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb18474a050>
# Uploading chunk  243
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb184df1c50>
# Uploading chunk  244
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb18c843110>
# Uploading chunk  245
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb18d209b50>
# Uploading chunk  246
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb1837116d0>
# Uploading chunk  247
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb184f53250>
# Uploading chunk  248
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb186bedbd0>
# Uploading chunk  249
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb183ca7dd0>
# Uploading chunk  250
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb18e0ab110>
# Uploading chunk  251
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb184d448d0>
# Uploading chunk  252
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb184d72150>
# Uploading chunk  253
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb18d659450>
# Uploading chunk  254
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb18d649a90>
# Uploading chunk  255
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb186571e90>
# Uploading chunk  256
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb188882190>
# Uploading chunk  257
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb18529e390>
# Uploading chunk  258
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb1833277d0>
# Uploading chunk  259
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb18624a450>
# Uploading chunk  260
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb1845afdd0>
# Uploading chunk  261
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb185bd82d0>
# Uploading chunk  262
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb188f4abd0>
# Uploading chunk  263
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb187475690>
# Uploading chunk  264
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb188905110>
# Uploading chunk  265
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb186c00b10>
# Uploading chunk  266
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb186e82d90>
# Uploading chunk  267
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb1888b5950>
# Uploading chunk  268
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb188ea2b90>
# Uploading chunk  269
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb17feb2150>
# Uploading chunk  270
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb1890fd910>
# Uploading chunk  271
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb183531e50>
# Uploading chunk  272
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb18352ebd0>
# Uploading chunk  273
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb18e0a2a50>
# Uploading chunk  274
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb180ee2890>
# Uploading chunk  275
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb1885ed2d0>
# Uploading chunk  276
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb1889a7750>
# Uploading chunk  277
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb1843f3690>
# Uploading chunk  278
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb184436a50>
# Uploading chunk  279
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb17f977dd0>
# Uploading chunk  280
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb1845a9690>
# Uploading chunk  281
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb18d76ddd0>
# Uploading chunk  282
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb18d3356d0>
# Uploading chunk  283
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb1837dd610>
# Uploading chunk  284
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb1837dfe50>
# Uploading chunk  285
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb1843f2310>
# Uploading chunk  286
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb1888d1bd0>
# Uploading chunk  287
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb18d7a1050>
# Uploading chunk  288
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb180f18050>
# Uploading chunk  289
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb186627610>
# Uploading chunk  290
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb18667c910>
# Uploading chunk  291
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb18b167b90>
# Uploading chunk  292
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb1884baf10>
# Uploading chunk  293
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb183e4fb90>
# Uploading chunk  294
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb184a266d0>
# Uploading chunk  295
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb18449bcd0>
# Uploading chunk  296
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb18448f590>
# Uploading chunk  297
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb18385cf90>
# Uploading chunk  298
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb1804479d0>
# Uploading chunk  299
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb17f1ea1d0>
# Uploading chunk  300
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb184fb2090>
# Uploading chunk  301
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb18c90ebd0>
# Uploading chunk  302
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb18c9076d0>
# Uploading chunk  303
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb18b156610>
# Uploading chunk  304
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb184744b50>
# Uploading chunk  305
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb184928a90>
# Uploading chunk  306
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb18e807b90>
# Uploading chunk  307
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb18d660250>
# Uploading chunk  308
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb18d676390>
# Uploading chunk  309
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb185bee6d0>
# Uploading chunk  310
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb17ffbfd10>
# Uploading chunk  311
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb184c8ac10>
# Uploading chunk  312
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb188962c90>
# Uploading chunk  313
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb185804a10>
# Uploading chunk  314
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb18593c610>
# Uploading chunk  315
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb18d5e2f50>
# Uploading chunk  316
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb186584650>
# Uploading chunk  317
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb188698050>
# Uploading chunk  318
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb186756090>
# Uploading chunk  319
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb18e1d8b50>
# Uploading chunk  320
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb186775150>
# Uploading chunk  321
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb18d5ff8d0>
# Uploading chunk  322
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb18643fb90>
# Uploading chunk  323
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb186fd8c10>
# Uploading chunk  324
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb17fe97e10>
# Uploading chunk  325
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb185d19210>
# Uploading chunk  326
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb185d0df90>
# Uploading chunk  327
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb18d506dd0>
# Uploading chunk  328
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb183709fd0>
# Uploading chunk  329
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb188f66650>
# Uploading chunk  330
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb18d4918d0>
# Uploading chunk  331
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb193f59250>
# Uploading chunk  332
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb193f3ae90>
# Uploading chunk  333
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb1858fa9d0>
# Uploading chunk  334
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb185cb9b90>
# Uploading chunk  335
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb185c07850>
# Uploading chunk  336
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb186b5dbd0>
# Uploading chunk  337
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb183a02410>
# Uploading chunk  338
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb1839c0210>
# Uploading chunk  339
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb1847c1990>
# Uploading chunk  340
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb180a29550>
# Uploading chunk  341
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb183c20bd0>
# Uploading chunk  342
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb188950050>
# Uploading chunk  343
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb1843e6750>
# Uploading chunk  344
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb184898990>
# Uploading chunk  345
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb184d6e7d0>
# Uploading chunk  346
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb18d652c50>
# Uploading chunk  347
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb18469ddd0>
# Uploading chunk  348
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb18680ab50>
# Uploading chunk  349
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb18410a8d0>
# Uploading chunk  350
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb183fe98d0>
# Uploading chunk  351
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb1841ca450>
# Uploading chunk  352
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb184210a10>
# Uploading chunk  353
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb1888c3410>
# Uploading chunk  354
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb180d30cd0>
# Uploading chunk  355
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb185e2d510>
# Uploading chunk  356
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb185e28210>
# Uploading chunk  357
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb1846b33d0>
# Uploading chunk  358
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb1806f7710>
# Uploading chunk  359
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb18582b450>
# Uploading chunk  360
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb180be4410>
# Uploading chunk  361
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb185e99290>
# Uploading chunk  362
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb185e9a1d0>
# Uploading chunk  363
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb18d446c50>
# Uploading chunk  364
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb18726e790>
# Uploading chunk  365
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb184c0c890>
# Uploading chunk  366
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb185807fd0>
# Uploading chunk  367
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb1862b9150>
# Uploading chunk  368
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb1862b6ed0>
# Uploading chunk  369
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb18c946610>
# Uploading chunk  370
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb18866dfd0>
# Uploading chunk  371
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb1852075d0>
# Uploading chunk  372
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb185130610>
# Uploading chunk  373
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb18670d1d0>
# Uploading chunk  374
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb186cd9fd0>
# Uploading chunk  375
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb18c843850>
# Uploading chunk  376
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb1806d34d0>
# Uploading chunk  377
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb188e4fbd0>
# Uploading chunk  378
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb1886c9590>
# Uploading chunk  379
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb1886d7c50>
# Uploading chunk  380
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb188d3bc50>
# Uploading chunk  381
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb18d5bff50>
# Uploading chunk  382
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb17fd3e590>
# Uploading chunk  383
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb18d7e1110>
# Uploading chunk  384
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb18449bbd0>
# Uploading chunk  385
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb18d321a10>
# Uploading chunk  386
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb18d4df610>
# Uploading chunk  387
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb185f8be90>
# Uploading chunk  388
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb188816f50>
# Uploading chunk  389
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb186086c10>
# Uploading chunk  390
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb17f00aed0>
# Uploading chunk  391
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb180e01110>
# Uploading chunk  392
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb17fc3b650>
# Uploading chunk  393
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb18d323850>
# Uploading chunk  394
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb1831e7850>
# Uploading chunk  395
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb1839e6110>
# Uploading chunk  396
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb1885f15d0>
# Uploading chunk  397
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb185b535d0>
# Uploading chunk  398
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb185b470d0>
# Uploading chunk  399
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb180a2fa50>
# Uploading chunk  400
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb18606d710>
# Uploading chunk  401
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb18606dc90>
# Uploading chunk  402
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb1861c1e50>
# Uploading chunk  403
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb188ded350>
# Uploading chunk  404
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb18d791810>
# Uploading chunk  405
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb1866ef8d0>
# Uploading chunk  406
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb186d26e50>
# Uploading chunk  407
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb180648850>
# Uploading chunk  408
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb19405e410>
# Uploading chunk  409
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb186a91c10>
# Uploading chunk  410
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb1870ea950>
# Uploading chunk  411
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb188dea110>
# Uploading chunk  412
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb180516050>
# Uploading chunk  413
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb18566d410>
# Uploading chunk  414
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb18e096e90>
# Uploading chunk  415
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb188b80d90>
# Uploading chunk  416
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb188c72dd0>
# Uploading chunk  417
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb187206990>
# Uploading chunk  418
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb1842a6a10>
# Uploading chunk  419
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb183ba1c50>
# Uploading chunk  420
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb188b80bd0>
# Uploading chunk  421
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb18d415b50>
# Uploading chunk  422
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb18d415890>
# Uploading chunk  423
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb18df0ea90>
# Uploading chunk  424
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb18463a610>
# Uploading chunk  425
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb183fffc50>
# Uploading chunk  426
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb18447b550>
# Uploading chunk  427
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb18453ded0>
# Uploading chunk  428
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb184514c50>
# Uploading chunk  429
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb180ec2790>
# Uploading chunk  430
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb1841bc3d0>
# Uploading chunk  431
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb183b24c90>
# Uploading chunk  432
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb186098290>
# Uploading chunk  433
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb1812e88d0>
# Uploading chunk  434
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb1812e8410>
# Uploading chunk  435
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb1846bdf90>
# Uploading chunk  436
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb18844ac10>
# Uploading chunk  437
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb184e76410>
# Uploading chunk  438
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb183d87890>
# Uploading chunk  439
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb1885d32d0>
# Uploading chunk  440
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb1885c5710>
# Uploading chunk  441
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb184c35050>
# Uploading chunk  442
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb188f7ce90>
# Uploading chunk  443
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb185a03ed0>
# Uploading chunk  444
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb181caea10>
# Uploading chunk  445
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb188ca09d0>
# Uploading chunk  446
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb188caf450>
# Uploading chunk  447
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb186c95e50>
# Uploading chunk  448
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb18b142410>
# Uploading chunk  449
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb18d2c7ed0>
# Uploading chunk  450
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb18089bd90>
# Uploading chunk  451
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb185d99fd0>
# Uploading chunk  452
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb18c8ee550>
# Uploading chunk  453
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb183b2a2d0>
# Uploading chunk  454
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb1852e3c50>
# Uploading chunk  455
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb17f34e590>
# Uploading chunk  456
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb17f1d8990>
# Uploading chunk  457
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb181abbb50>
# Uploading chunk  458
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb185d17610>
# Uploading chunk  459
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb183bbe750>
# Uploading chunk  460
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb185df6590>
# Uploading chunk  461
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb1843ae710>
# Uploading chunk  462
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb18e1a60d0>
# Uploading chunk  463
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb184159950>
# Uploading chunk  464
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb18414de90>
# Uploading chunk  465
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb18c954550>
# Uploading chunk  466
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb18702db90>
# Uploading chunk  467
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb188924210>
# Uploading chunk  468
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb1861bae10>
# Uploading chunk  469
# ...
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb18740a150>
# Uploading chunk  773
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb18694f710>
# Uploading chunk  774
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb188c44350>
# Uploading chunk  775
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb18694a050>
# Uploading chunk  776
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb1807f4d50>
# Uploading chunk  777
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb184f5e390>
# Uploading chunk  778
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb186760c10>
# Uploading chunk  779
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb187195910>
# Uploading chunk  780
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb186387a90>
# Uploading chunk  781
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb18639f710>
# Uploading chunk  782
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb183cac6d0>
# Uploading chunk  783
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb18c89ba10>
# Uploading chunk  784
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb183c246d0>
# Uploading chunk  785
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb18d7d5b50>
# Uploading chunk  786
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb17ff72910>
# Uploading chunk  787
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb17ff45e10>
# Uploading chunk  788
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb18ddf9ed0>
# Uploading chunk  789
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb17faae910>
# Uploading chunk  790
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb1856cd490>
# Uploading chunk  791
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb18de51810>
# Uploading chunk  792
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb1854ee310>
# Uploading chunk  793
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb1854ee750>
# Uploading chunk  794
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb1843d2190>
# Uploading chunk  795
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb18553c350>
# Uploading chunk  796
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb1849c1210>
# Uploading chunk  797
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb1831cff10>
# Uploading chunk  798
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb17fcd01d0>
# Uploading chunk  799
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb17fcd05d0>
# Uploading chunk  800
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb1810caf90>
# Uploading chunk  801
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb186de9cd0>
# Uploading chunk  802
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb1842ab190>
# Uploading chunk  803
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb18e7e4ad0>
# Uploading chunk  804
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb185e62250>
# Uploading chunk  805
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb185e3fd50>
# Uploading chunk  806
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb188930250>
# Uploading chunk  807
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb18679c1d0>
# Uploading chunk  808
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb180914550>
# Uploading chunk  809
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb1844c8050>
# Uploading chunk  810
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb1874a34d0>
# Uploading chunk  811
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb18916d710>
# Uploading chunk  812
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb185eb5d50>
# Uploading chunk  813
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb185fb2c10>
# Uploading chunk  814
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb1809f7910>
# Uploading chunk  815
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb185c3b710>
# Uploading chunk  816
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb18e23ea50>
# Uploading chunk  817
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb188da7ed0>
# Uploading chunk  818
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb180743610>
# Uploading chunk  819
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb1806e3890>
# Uploading chunk  820
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb1860f3690>
# Uploading chunk  821
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb1886c4cd0>
# Uploading chunk  822
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb1886e4990>
# Uploading chunk  823
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb18dfab910>
# Uploading chunk  824
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb1868a0250>
# Uploading chunk  825
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb18d3907d0>
# Uploading chunk  826
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb186863f90>
# Uploading chunk  827
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb18d7c2910>
# Uploading chunk  828
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb18c8f3810>
# Uploading chunk  829
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb18c905cd0>
# Uploading chunk  830
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb185bfaed0>
# Uploading chunk  831
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb1845a4fd0>
# Uploading chunk  832
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb188e55b90>
# Uploading chunk  833
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb1859ebb90>
# Uploading chunk  834
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb188758fd0>
# Uploading chunk  835
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb1887545d0>
# Uploading chunk  836
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb17fbd9290>
# Uploading chunk  837
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb18553a890>
# Uploading chunk  838
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb18385ae50>
# Uploading chunk  839
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb188b56d90>
# Uploading chunk  840
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb18661cb50>
# Uploading chunk  841
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb18661e550>
# Uploading chunk  842
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb18df1fa10>
# Uploading chunk  843
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb18d66f9d0>
# Uploading chunk  844
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb18d66f6d0>
# Uploading chunk  845
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb185c39c50>
# Uploading chunk  846
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb181b37190>
# Uploading chunk  847
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb181a2a210>
# Uploading chunk  848
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb1852c7c90>
# Uploading chunk  849
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb183b89a50>
# Uploading chunk  850
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb18d6ef310>
# Uploading chunk  851
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb183f7ec10>
# Uploading chunk  852
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb183922090>
# Uploading chunk  853
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb1839a2110>
# Uploading chunk  854
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb186a83d10>
# Uploading chunk  855
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb187437510>
# Uploading chunk  856
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb185b82e50>
# Uploading chunk  857
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb18872df10>
# Uploading chunk  858
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb180f59750>
# Uploading chunk  859
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb17fc77090>
# Uploading chunk  860
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb185f2ab10>
# Uploading chunk  861
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb1840f77d0>
# Uploading chunk  862
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb181434910>
# Uploading chunk  863
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb17f1f1e90>
# Uploading chunk  864
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb183e31150>
# Uploading chunk  865
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb1841254d0>
# Uploading chunk  866
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb188665bd0>
# Uploading chunk  867
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb184d6b450>
# Uploading chunk  868
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb183c28490>
# Uploading chunk  869
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb17ffd3fd0>
# Uploading chunk  870
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb184d2e750>
# Uploading chunk  871
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb184a5a850>
# Uploading chunk  872
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb1810dfbd0>
# Uploading chunk  873
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb18d65e090>
# Uploading chunk  874
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb1804ba910>
# Uploading chunk  875
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb18d6ed510>
# Uploading chunk  876
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb17fc2a2d0>
# Uploading chunk  877
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb17fc2a8d0>
# Uploading chunk  878
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb18423ae90>
# Uploading chunk  879
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb186377f90>
# Uploading chunk  880
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb1849db5d0>
# Uploading chunk  881
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb180eeafd0>
# Uploading chunk  882
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb17f1eea90>
# Uploading chunk  883
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb17f1ca150>
# Uploading chunk  884
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb18c844bd0>
# Uploading chunk  885
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb188506410>
# Uploading chunk  886
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb1872b3490>
# Uploading chunk  887
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb1862bf350>
# Uploading chunk  888
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb181bf1a50>
# Uploading chunk  889
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb1862bfa50>
# Uploading chunk  890
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb1889340d0>
# Uploading chunk  891
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb185101450>
# Uploading chunk  892
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb18416b4d0>
# Uploading chunk  893
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb187479bd0>
# Uploading chunk  894
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb186284bd0>
# Uploading chunk  895
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb186284f90>
# Uploading chunk  896
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb1809e7e50>
# Uploading chunk  897
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb180a307d0>
# Uploading chunk  898
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb188cf5c10>
# Uploading chunk  899
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb18d741790>
# Uploading chunk  900
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb18d3f0250>
# Uploading chunk  901
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb181b56150>
# Uploading chunk  902
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb18c95ca50>
# Uploading chunk  903
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb180a57210>
# Uploading chunk  904
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb18889f850>
# Uploading chunk  905
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb189033810>
# Uploading chunk  906
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb183208310>
# Uploading chunk  907
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb1857a4f90>
# Uploading chunk  908
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb184fb2890>
# Uploading chunk  909
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb185c4c6d0>
# Uploading chunk  910
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb18601fb50>
# Uploading chunk  911
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb183a77610>
# Uploading chunk  912
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb185b9bc90>
# Uploading chunk  913
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb185bbb690>
# Uploading chunk  914
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb183ff1910>
# Uploading chunk  915
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb18d678b90>
# Uploading chunk  916
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb18094f690>
# Uploading chunk  917
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb188794fd0>
# Uploading chunk  918
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb1870a6550>
# Uploading chunk  919
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb1870a6e10>
# Uploading chunk  920
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb183cb2250>
# Uploading chunk  921
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb181c52150>
# Uploading chunk  922
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb188565ed0>
# Uploading chunk  923
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb17f08df50>
# Uploading chunk  924
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb18e1e4f50>
# Uploading chunk  925
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb18118f0d0>
# Uploading chunk  926
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb18d5b0c10>
# Uploading chunk  927
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb18000a7d0>
# Uploading chunk  928
# Uploaded DF to BQ:  <google.cloud.bigquery.job.LoadJob object at 0x7fb1804760d0>

# %%
#Wikidata table schema
print(chunk.dtypes)
# Out:
# QID            object
# Label          object
# Description    object
# dtype: object
